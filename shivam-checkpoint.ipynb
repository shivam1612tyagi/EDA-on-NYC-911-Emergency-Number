# %% [markdown]
# # Final project

# %% [markdown]
# #                   ~Shivam Tyagi                      shivam1612tyagi@gmail.com

# %% [markdown]
# ### Question:-Exploratory Data Analysis of NYC 911 Emergency Number. Includes data manipulation using pandas library, days of the week working with datetime, visualization with matplotlib and seaborn,

# %% [markdown]
# # import libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import style 
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# # version of pandas

# %%
pd.__version__
# Out:
# '1.0.1'

# %% [markdown]
# # Read CSV file

# %%
filepath=r"C:\Users\admin\Desktop\911_End-to-End_Data - 911_End-to-End_Data.csv"
df=pd.read_csv(filepath)
df
# Out:
#      Week_Start_Date Agency                      Final Incident Type  \
# 0          6/24/2019    EMS        1. Life Threating Med Emergencies
# 1          6/24/2019    EMS  2. Non-Life Threatening Med Emergencies
# 2          6/24/2019   FDNY                      1. Structural Fires
# 3          6/24/2019   FDNY                  2. Non-Structural Fires
# 4          6/24/2019   FDNY                   3. Medical Emergencies
# ...              ...    ...                                      ...
# 2495      10/31/2016    EMS        1. Life Threating Med Emergencies
# 2496      10/31/2016    EMS  2. Non-Life Threatening Med Emergencies
# 2497      10/31/2016   FDNY                      1. Structural Fires
# 2498      10/31/2016   FDNY                  2. Non-Structural Fires
# 2499      10/31/2016   FDNY                   3. Medical Emergencies
#
#       of_Incidents_Calculated  Call to First Pickup  \
# 0                        7801                  4.51
# ...

# %% [markdown]
# # Head function()

# %%
df.head()
# Out:
#   Week_Start_Date Agency                      Final Incident Type  \
# 0       6/24/2019    EMS        1. Life Threating Med Emergencies
# 1       6/24/2019    EMS  2. Non-Life Threatening Med Emergencies
# 2       6/24/2019   FDNY                      1. Structural Fires
# 3       6/24/2019   FDNY                  2. Non-Structural Fires
# 4       6/24/2019   FDNY                   3. Medical Emergencies
#
#    of_Incidents_Calculated  Call to First Pickup  \
# 0                     7801                  4.51
# 1                    11329                  4.48
# 2                      171                  4.41
# 3                      124                  5.02
# 4                     3039                  4.42
#
#    Call to PD Calltaker Handoff  Call to FDNY Pickup  \
# 0                         65.37                  NaN
# 1                         77.69                  NaN
# 2                         30.40                36.36
# ...

# %% [markdown]
# # Tail function()

# %%
df.tail()
# Out:
#      Week_Start_Date Agency                      Final Incident Type  \
# 2495      10/31/2016    EMS        1. Life Threating Med Emergencies
# 2496      10/31/2016    EMS  2. Non-Life Threatening Med Emergencies
# 2497      10/31/2016   FDNY                      1. Structural Fires
# 2498      10/31/2016   FDNY                  2. Non-Structural Fires
# 2499      10/31/2016   FDNY                   3. Medical Emergencies
#
#       of_Incidents_Calculated  Call to First Pickup  \
# 2495                     9289                  4.04
# 2496                    12457                  3.93
# 2497                      245                  3.47
# 2498                      175                  3.81
# 2499                     2041                  3.49
#
#       Call to PD Calltaker Handoff  Call to FDNY Pickup  \
# 2495                         61.78                  NaN
# 2496                         81.78                  NaN
# 2497                         80.79                  NaN
# ...

# %% [markdown]
# # Describe function

# %%
df.describe(include='all').T
# Out:
#                                                    count unique  \
# Week_Start_Date                                     2500    139
# Agency                                              2500      4
# Final Incident Type                                 2500     21
# of_Incidents_Calculated                             2500    NaN
# Call to First Pickup                                2500    NaN
# Call to PD Calltaker Handoff                        2500    NaN
# Call to FDNY Pickup                                  201    NaN
# Call_to_FDNY_Job_Creation                            201    NaN
# Call to EMS Pickup                                   417    NaN
# Call_to_Agency_Job_Creation                          417    NaN
# Call_to_Agency_Dispatch                             2500    NaN
# Call_to_Agency_Arrival                              2500    NaN
# Call_to_First_Arrival(Multi-Agency Incidents)       2500    NaN
# Median Pickup                                       2500    NaN
# ...

# %% [markdown]
# # info function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 30 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Week_Start_Date                                          2500 non-null   object
#  1   Agency                                                   2500 non-null   object
#  2   Final Incident Type                                      2500 non-null   object
#  3   of_Incidents_Calculated                                  2500 non-null   int64
#  4   Call to First Pickup                                     2500 non-null   float64
#  5   Call to PD Calltaker Handoff                             2500 non-null   float64
#  6   Call to FDNY Pickup                                      201 non-null    float64
#  7   Call_to_FDNY_Job_Creation                                201 non-null    float64
# ...

# %% [markdown]
# # Length of the CSV file

# %%
print('size: %d' % len(df))
# Out:
# size: 2500

# %% [markdown]
# # type of data

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Columns in CSV file

# %%
df.columns
# Out:
# Index(['Week_Start_Date', 'Agency', 'Final Incident Type',
#        'of_Incidents_Calculated', 'Call to First Pickup',
#        'Call to PD Calltaker Handoff', 'Call to FDNY Pickup',
#        'Call_to_FDNY_Job_Creation', 'Call to EMS Pickup',
#        'Call_to_Agency_Job_Creation', 'Call_to_Agency_Dispatch',
#        'Call_to_Agency_Arrival',
#        'Call_to_First_Arrival(Multi-Agency Incidents)', 'Median Pickup',
#        'Median Calltaker Handoff', 'Median_FDNY_Pickup',
#        'Median FDNY Job Creation', 'Median_Ems_Pickup',
#        'Median Ems Job Creation', 'Median_Dispatch', 'Median_Travel',
#        'Median_Cumulative_First_Arrival(Multi-Agency Incidents)',
#        'Average Travel', 'Average Dispatch', 'Average EMS Processing',
#        'Average EMS Pickup', 'Average Calltaker Processing', 'Average Pickup',
#        'Average FD Pickup', 'Average FD Processing'],
#       dtype='object')

# %% [markdown]
# # Nul  function

# %%
df.isnull()
# Out:
#       Week_Start_Date  Agency  Final Incident Type  of_Incidents_Calculated  \
# 0               False   False                False                    False
# 1               False   False                False                    False
# 2               False   False                False                    False
# 3               False   False                False                    False
# 4               False   False                False                    False
# ...               ...     ...                  ...                      ...
# 2495            False   False                False                    False
# 2496            False   False                False                    False
# 2497            False   False                False                    False
# 2498            False   False                False                    False
# 2499            False   False                False                    False
#
# ...

# %% [markdown]
# # number of null values in DataFrame

# %%
df.isnull().sum()
# Out:
# Week_Start_Date                                               0
# Agency                                                        0
# Final Incident Type                                           0
# of_Incidents_Calculated                                       0
# Call to First Pickup                                          0
# Call to PD Calltaker Handoff                                  0
# Call to FDNY Pickup                                        2299
# Call_to_FDNY_Job_Creation                                  2299
# Call to EMS Pickup                                         2083
# Call_to_Agency_Job_Creation                                2083
# Call_to_Agency_Dispatch                                       0
# Call_to_Agency_Arrival                                        0
# Call_to_First_Arrival(Multi-Agency Incidents)                 0
# Median Pickup                                                 0
# Median Calltaker Handoff                                      0
# ...

# %% [markdown]
# # Total number of null values in DataFrame

# %%
df.isnull().sum().sum()
# Out:
# 26292

# %% [markdown]
# # Number of Non-Null value

# %%
df.notnull().sum()
# Out:
# Week_Start_Date                                            2500
# Agency                                                     2500
# Final Incident Type                                        2500
# of_Incidents_Calculated                                    2500
# Call to First Pickup                                       2500
# Call to PD Calltaker Handoff                               2500
# Call to FDNY Pickup                                         201
# Call_to_FDNY_Job_Creation                                   201
# Call to EMS Pickup                                          417
# Call_to_Agency_Job_Creation                                 417
# Call_to_Agency_Dispatch                                    2500
# Call_to_Agency_Arrival                                     2500
# Call_to_First_Arrival(Multi-Agency Incidents)              2500
# Median Pickup                                              2500
# Median Calltaker Handoff                                   2500
# ...

# %% [markdown]
# # Total number of Non-Null Values

# %%
df.notnull().sum().sum()
# Out:
# 48708

# %% [markdown]
# ## overall values

# %% [markdown]
# Total number of Null values--->26292
# Total number of Non-Null values---->48708

# %% [markdown]
# ### removing null values to avoid errors

# %%
df.dropna(inplace = True)

# %% [markdown]
# # Dtype function

# %%
df.dtypes
# Out:
# Week_Start_Date                                             object
# Agency                                                      object
# Final Incident Type                                         object
# of_Incidents_Calculated                                      int64
# Call to First Pickup                                       float64
# Call to PD Calltaker Handoff                               float64
# Call to FDNY Pickup                                        float64
# Call_to_FDNY_Job_Creation                                  float64
# Call to EMS Pickup                                         float64
# Call_to_Agency_Job_Creation                                float64
# Call_to_Agency_Dispatch                                    float64
# Call_to_Agency_Arrival                                     float64
# Call_to_First_Arrival(Multi-Agency Incidents)              float64
# Median Pickup                                              float64
# ...

# %% [markdown]
# # Counts in Agency & plot

# %%
df['Agency'].value_counts()
# Out:
# NYPD (Non-CIP)    1253
# FDNY               555
# NYPD               414
# EMS                278
# Name: Agency, dtype: int64

# %%
sns.countplot(df['Agency'])

# %% [markdown]
# # Top 5 titles of emergency calls & plot

# %%
df['Final Incident Type'].value_counts()[:5]
# Out:
# 2. Non-Life Threatening Med Emergencies    139
# 3. Medical Emergencies                     139
# 1. Structural Fires                        139
# 2. Non-Structural Fires                    139
# 1. Life Threating Med Emergencies          139
# Name: Final Incident Type, dtype: int64

# %%
plt.figure(figsize=(8,6))
df.groupby('Final Incident Type').count().sort_values('of_Incidents_Calculated',ascending=0)[:5]['of_Incidents_Calculated'].plot(kind='barh')

# %% [markdown]
# # Dividing the Data by Police Department, Fire Department and Emergencies

# %%
#New York Fire Department
#FDNY = np.where(Agency == "FDNY")
#(df('Agency') == "FDNY")
print(np.where(df == "Agency"))
# Out:
# (array([], dtype=int32), array([], dtype=int32))
# D:\anoconda\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
fire_department = df[df['Agency'] == "FDNY"]
fire_department
# Out:
#      Week_Start_Date Agency         Final Incident Type  \
# 2          6/24/2019   FDNY         1. Structural Fires
# 3          6/24/2019   FDNY     2. Non-Structural Fires
# 4          6/24/2019   FDNY      3. Medical Emergencies
# 5          6/24/2019   FDNY  4. Non-Medical Emergencies
# 20         6/17/2019   FDNY         1. Structural Fires
# ...              ...    ...                         ...
# 2481       11/7/2016   FDNY      3. Medical Emergencies
# 2482       11/7/2016   FDNY  4. Non-Medical Emergencies
# 2497      10/31/2016   FDNY         1. Structural Fires
# 2498      10/31/2016   FDNY     2. Non-Structural Fires
# 2499      10/31/2016   FDNY      3. Medical Emergencies
#
#       of_Incidents_Calculated  Call to First Pickup  \
# 2                         171                  4.41
# 3                         124                  5.02
# 4                        3039                  4.42
# 5                        2301                  4.62
# ...

# %%
#New York Police Department
police_department = df[df['Agency'] == "NYPD"]
police_department
# Out:
#      Week_Start_Date Agency Final Incident Type  of_Incidents_Calculated  \
# 6          6/24/2019   NYPD         1. Critical                      988
# 7          6/24/2019   NYPD          2. Serious                     1919
# 8          6/24/2019   NYPD     3. Non-Critical                      441
# 24         6/17/2019   NYPD         1. Critical                     1247
# 25         6/17/2019   NYPD          2. Serious                     2523
# ...              ...    ...                 ...                      ...
# 2466      11/14/2016   NYPD          2. Serious                     2127
# 2467      11/14/2016   NYPD     3. Non-Critical                      762
# 2483       11/7/2016   NYPD         1. Critical                     1070
# 2484       11/7/2016   NYPD          2. Serious                     2259
# 2485       11/7/2016   NYPD     3. Non-Critical                      852
#
#       Call to First Pickup  Call to PD Calltaker Handoff  Call to FDNY Pickup  \
# ...

# %%
#New York Emergencies
emergencies = df[df['Agency'] == "EMS"]
emergencies
# Out:
#      Week_Start_Date Agency                      Final Incident Type  \
# 0          6/24/2019    EMS        1. Life Threating Med Emergencies
# 1          6/24/2019    EMS  2. Non-Life Threatening Med Emergencies
# 18         6/17/2019    EMS        1. Life Threating Med Emergencies
# 19         6/17/2019    EMS  2. Non-Life Threatening Med Emergencies
# 37         6/10/2019    EMS        1. Life Threating Med Emergencies
# ...              ...    ...                                      ...
# 2460      11/14/2016    EMS  2. Non-Life Threatening Med Emergencies
# 2477       11/7/2016    EMS        1. Life Threating Med Emergencies
# 2478       11/7/2016    EMS  2. Non-Life Threatening Med Emergencies
# 2495      10/31/2016    EMS        1. Life Threating Med Emergencies
# 2496      10/31/2016    EMS  2. Non-Life Threatening Med Emergencies
#
#       of_Incidents_Calculated  Call to First Pickup  \
# 0                        7801                  4.51
# ...

# %% [markdown]
# # Type of Date in DataFrame

# %%
type(df['Week_Start_Date'][0])
# Out:
# str

# %% [markdown]
# # Change Date Format

# %%
df['Week_Start_Date']=pd.to_datetime(df['Week_Start_Date'])
df
# Out:
#      Week_Start_Date Agency                      Final Incident Type  \
# 0         2019-06-24    EMS        1. Life Threating Med Emergencies
# 1         2019-06-24    EMS  2. Non-Life Threatening Med Emergencies
# 2         2019-06-24   FDNY                      1. Structural Fires
# 3         2019-06-24   FDNY                  2. Non-Structural Fires
# 4         2019-06-24   FDNY                   3. Medical Emergencies
# ...              ...    ...                                      ...
# 2495      2016-10-31    EMS        1. Life Threating Med Emergencies
# 2496      2016-10-31    EMS  2. Non-Life Threatening Med Emergencies
# 2497      2016-10-31   FDNY                      1. Structural Fires
# 2498      2016-10-31   FDNY                  2. Non-Structural Fires
# 2499      2016-10-31   FDNY                   3. Medical Emergencies
#
#       of_Incidents_Calculated  Call to First Pickup  \
# 0                        7801                  4.51
# ...

# %% [markdown]
# # Total number of Months in a DataFrame

# %%
time = df['Week_Start_Date'].iloc[0]
print('Month:',time.month)
# Out:
# Month: 6

# %%
print("Median:",df.of_Incidents_Calculated.median())
print("Mean:",df.of_Incidents_Calculated.mean())
print("Max Trip Distance:",df.of_Incidents_Calculated.max())
print("Min Trip Distance:",df.of_Incidents_Calculated.min())
print("Standard Deviation:",df.of_Incidents_Calculated.std())
# Out:
# Median: 2594.0
# Mean: 3480.5612
# Max Trip Distance: 15887
# Min Trip Distance: 1
# Standard Deviation: 3686.0435329259476

# %% [markdown]
# # Histogram of Each Department

# %%
df['Agency'].hist()
plt.title('Fire Department, Police Department, Emergencies',fontsize=15)
plt.xlabel("FDNY, NYPD, EMS", fontsize=15)
plt.ylabel("Frequency",fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
fire_department['Agency'].hist()
plt.title('Fire Department',fontsize=15)
plt.xlabel("FDNY", fontsize=15)
plt.ylabel("Frequency",fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
police_department['Agency'].hist()
plt.title('Police Department',fontsize=15)
plt.xlabel("PD", fontsize=15)
plt.ylabel("Frequency",fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
emergencies['Agency'].hist()
plt.title('Emergencies',fontsize=15)
plt.xlabel("EMS", fontsize=15)
plt.ylabel("Frequency",fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## It's very hard to understand the diagram.

# %% [markdown]
# ### However, the diagrams show that the frequency of call to each of the departments is very high.

# %% [markdown]
# # CORRELATION

# %% [raw]
# Important feature to correlate data for each department: Final Incident Type (column)
#
# -Clasiffication of Incident Type on each department
# -Incident Type average
# -Most Commom incident type calls
# -Correlation between Agency and Final Incident Type

# %%
#General Scatter plot with incident Type by department
plt.scatter(df['Agency'], df['Final Incident Type'], alpha = 0.05)
plt.xlabel('Agency',fontsize=12)
plt.ylabel('Final Incident Type',fontsize=12)
# Out:
# Text(0, 0.5, 'Final Incident Type')

# %% [raw]
# -Incident type for each department
#  -EMS(Emergency), FDNY(Fire Department), NYPD(Police Department)

# %%
plt.scatter(fire_department['of_Incidents_Calculated'], fire_department['Final Incident Type'])

# %%
#Scatter Plot Correlation of Fire Department Incident Types
plt.scatter(fire_department['Final Incident Type'], fire_department['of_Incidents_Calculated'], alpha = 0.05)
plt.xlabel('Final Incident Type',fontsize=15)
plt.ylabel('# of Incidents Calculated',fontsize=15)
# Out:
# Text(0, 0.5, '# of Incidents Calculated')

# %%
#Correlaation between all columns in dataset for the fire_department
fire_department.corr()
# Out:
#                                                     of_Incidents_Calculated  \
# of_Incidents_Calculated                                            1.000000
# Call to First Pickup                                               0.059425
# Call to PD Calltaker Handoff                                       0.792003
# Call to FDNY Pickup                                                0.928378
# Call_to_FDNY_Job_Creation                                          0.123379
# Call to EMS Pickup                                                 0.580913
# Call_to_Agency_Job_Creation                                        0.500062
# Call_to_Agency_Dispatch                                            0.748321
# Call_to_Agency_Arrival                                             0.828273
# Call_to_First_Arrival(Multi-Agency Incidents)                      0.781119
# Median Pickup                                                     -0.073049
# ...

# %%
#Correlation:FDNY Final Incident vs # of Incident Types Calculated
plt.scatter(fire_department['Final Incident Type'], fire_department['of_Incidents_Calculated'], alpha = 0.50)
plt.xlabel('Final Incident Type',fontsize=15 )
plt.ylabel('# of Incidents Calculated',fontsize=15)
# Out:
# Text(0, 0.5, '# of Incidents Calculated')

# %% [raw]
# -It shows a bigger number of incidents for Medical Emergencies and Non Medical emergencies
# -However for Structural and Non structural fire the incidents are smaller
# -between 0 to 1000 for Structural and Non Structural Fire
# -Between 2000 and 4500 for Medical and Non Medical Emergencies

# %%
police_department.corr()
# Out:
#                                                     of_Incidents_Calculated  \
# of_Incidents_Calculated                                            1.000000
# Call to First Pickup                                               0.056781
# Call to PD Calltaker Handoff                                      -0.638187
# Call to FDNY Pickup                                                     NaN
# Call_to_FDNY_Job_Creation                                               NaN
# Call to EMS Pickup                                                      NaN
# Call_to_Agency_Job_Creation                                             NaN
# Call_to_Agency_Dispatch                                           -0.534010
# Call_to_Agency_Arrival                                            -0.502905
# Call_to_First_Arrival(Multi-Agency Incidents)                     -0.510824
# Median Pickup                                                           NaN
# ...

# %%
#Police Department
plt.scatter(police_department['Final Incident Type'], police_department['of_Incidents_Calculated'], alpha = 0.50)
plt.xlabel('Final Incident Type',fontsize=12)
plt.ylabel('# of Incidents Calculated',fontsize=12)
# Out:
# Text(0, 0.5, '# of Incidents Calculated')

# %% [raw]
# -The bigger of Incidents calculated are for Serios Incidents between 1500 and 3000
# -Critical Incidents goes from 700 to 1200
# -Non Critical has the smaller # of incidents less than 1000

# %%
emergencies.corr()
# Out:
#                                                     of_Incidents_Calculated  \
# of_Incidents_Calculated                                            1.000000
# Call to First Pickup                                               0.020141
# Call to PD Calltaker Handoff                                       0.826129
# Call to FDNY Pickup                                                     NaN
# Call_to_FDNY_Job_Creation                                               NaN
# Call to EMS Pickup                                                 0.839869
# Call_to_Agency_Job_Creation                                       -0.192321
# Call_to_Agency_Dispatch                                            0.771734
# Call_to_Agency_Arrival                                             0.912685
# Call_to_First_Arrival(Multi-Agency Incidents)                      0.920423
# Median Pickup                                                           NaN
# ...

# %%
#Emergencies
plt.scatter(emergencies['Final Incident Type'], emergencies['of_Incidents_Calculated'], alpha = 0.5)
plt.xlabel('Final Incident Type',fontsize=15)
plt.ylabel('# of Incidents Calculated',fontsize=15)
# Out:
# Text(0, 0.5, '# of Incidents Calculated')

# %% [raw]
# -The bigger # of incidents goes to Non-Life Threatening Medical Emergencies between 11000 and 16000
# -Life Threatening Med Emergencies has a smaller # of incidents between 8000 and 11000

# %% [markdown]
# # Chart between Call to First pickup & PD calltaker Handoff

# %%
x=df['Call to First Pickup']
data=df['Call to PD Calltaker Handoff']
plt.hist([x,data],color=['k','g'],rwidth=0.9,label=["Call to First Pickup","Call to PD Calltaker Handoff"])
plt.xlabel("call process",fontsize="20")
plt.legend()

# %% [markdown]
# if we reduce the First pickup time and give call directly to the PD caller then the number of cases may be drecreses

# %%
sns.relplot('Final Incident Type','of_Incidents_Calculated',data=df)

# %% [markdown]
# # Chart between Agency vs of Incidents Calculated

# %%
plt.scatter(df['Agency'],df['of_Incidents_Calculated'],c='r')
plt.title("Agency vs of Incidents Calculated",fontsize=20)
plt.xlabel('Agency',fontsize=20)
plt.ylabel("Incidents Calculated",fontsize=20)
plt.show()

# %% [markdown]
# most of the "of Incidents Calculated" by NYPD(Non-CIP) agency

# %% [markdown]
# # Chart of Call to FDNY Pickup

# %%
plt.hist(df['Call to FDNY Pickup'],color="green",edgecolor="white",bins=5)
plt.title('Call to FDNY Pickup',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
plt.xlabel('call pickup by FDNY',fontsize=20)
# Out:
# D:\anoconda\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# D:\anoconda\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# Text(0.5, 0, 'call pickup by FDNY')

# %% [markdown]
# most of the call duration lies between 30-35. & less call duration lies b/w 40-45.

# %% [markdown]
# # Chart of Call to FDNY Job Creation

# %%
plt.hist(df['Call_to_FDNY_Job_Creation'],color="yellow",edgecolor="white",bins=5)
plt.title('Call to FDNY Job Creation',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
plt.xlabel('call pickup by FDNY Job Creation',fontsize=20)
# Out:
# Text(0.5, 0, 'call pickup by FDNY Job Creation')

# %% [markdown]
# all the call lies b/w 100-200

# %% [markdown]
# # Chart of Call to EMS Pickup

# %%
plt.hist(df['Call to EMS Pickup'],color="m",edgecolor="white",bins=5)
plt.ylabel('Frequency',fontsize=20)
plt.xlabel('Call to EMS Pickup',fontsize=20)
# Out:
# Text(0.5, 0, 'Call to EMS Pickup')

# %% [markdown]
# call pickup by EMS is peak on 70-80 & lower lies on 50-60

# %% [markdown]
# # Chart of "Call to Agency Job Creation"

# %%
plt.hist(df['Call_to_Agency_Job_Creation'],color="blue",edgecolor="white",bins=5)
plt.title('Call to Agency Job Creation',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
plt.xlabel('Call to Agency Job Creation',fontsize=20)
# Out:
# Text(0.5, 0, 'Call to Agency Job Creation')

# %% [markdown]
# maximum--> 100-50
# minimum-->25(approx)- 100

# %% [markdown]
# # Comparsion b/w "Call_to_Agency_Job_Creation vs Call_to_FDNY_Job_Creation"

# %%
plt.hist([df.Call_to_Agency_Job_Creation,df.Call_to_FDNY_Job_Creation],rwidth=0.9, color=["g","k"],bins=3,label=['Call_to_Agency_Job_Creation','Call_to_FDNY_Job_Creation'])
plt.title('Call_to_Agency_Job_Creation vs Call_to_FDNY_Job_Creation',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
plt.legend()

# %% [markdown]
# its show that most of the call came to Agency job creation

# %% [markdown]
# # Chart of "Call_to_Agency_Dispatch"

# %%
plt.hist(df['Call_to_Agency_Dispatch'],color="m",edgecolor="white",bins=4)
plt.title('Call to Agency Dispatch',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
plt.xlabel('Call to Agency Dispatch',fontsize=20)
# Out:
# Text(0.5, 0, 'Call to Agency Dispatch')

# %% [markdown]
# # Chart of "Call_to_Agency_Arrival"

# %%
plt.hist(df['Call_to_Agency_Arrival'],color="g",edgecolor="white",bins=5)
plt.title('Call to Agency Arrival',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
plt.xlabel('Call to Agency Arrival',fontsize=20)
# Out:
# Text(0.5, 0, 'Call to Agency Arrival')

# %% [markdown]
# # Comparsion b/w "Call_to_Agency_Job_Dispatch vs Call_to_Agency_Arrival"

# %%
plt.hist([df.Call_to_Agency_Dispatch,df.Call_to_Agency_Arrival],rwidth=0.9, color=["g","k"],bins=3,label=['Call_to_Agency_Job_Dispatch','Call_to_Agency_Arrival'])
plt.title('Call_to_Agency_Job_Dispatch vs Call_to_Agency_Arrival',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
plt.legend()

# %% [markdown]
# # comparsion chart b/w "Agency vs Call_to_First_Arrival(Multi-Agency Incidents)"

# %%
plt.scatter(df['Agency'],df['Call_to_First_Arrival(Multi-Agency Incidents)'],c='r')
plt.title("Agency vs Call_to_First_Arrival(Multi-Agency Incidents)",fontsize=20)
plt.xlabel('Agency',fontsize=20)
plt.ylabel("Call arrival",fontsize=20)
plt.show()

# %% [markdown]
# most of the first call arrival come on NYPD(Non-CIP)

# %% [markdown]
# # comparsion b/w "Median_FDNY_Pickup vs Median_Ems_Pickup"

# %%
plt.hist([df.Median_FDNY_Pickup,df.Median_Ems_Pickup],rwidth=0.9, color=["g","y"],bins=3,label=['Median_FDNY_Pickup','Median_Ems_Pickup'])
plt.title('Median_FDNY_Pickup vs Median_Ems_Pickup',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
plt.legend()

# %% [markdown]
# median EMS has highest number of pickup

# %% [markdown]
# # Comparsion b/w "Median_Dispatch vs Median_Travel"

# %%
plt.hist([df.Median_Dispatch,df.Median_Travel],rwidth=0.9, color=["r","g"],bins=3,label=['Median_Dispatch','Median_Travel'])
plt.title('Median_Dispatch vs Median_Travel',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
plt.legend()

# %% [markdown]
# # Comparsion b/w "Agency vs Median_Cumulative_First_Arrival(Multi-Agency Incidents)"

# %%
plt.scatter(df['Agency'],df['Median_Cumulative_First_Arrival(Multi-Agency Incidents)'],c='m')
plt.title("Agency vs Median_Cumulative_First_Arrival(Multi-Agency Incidents)",fontsize=20)
plt.xlabel('Agency',fontsize=20)
plt.show()

# %% [markdown]
# # Histogram Chart of all the Columns

# %%
df.hist(figsize=(20,30),bins=3,alpha=0.9)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0DFADBD0>,
# ...
#       dtype=object)

# %%
#FDNY
fire_department.describe().T
# Out:
#                                                     count         mean  \
# of_Incidents_Calculated                             555.0  1685.664865
# Call to First Pickup                                555.0     3.546252
# Call to PD Calltaker Handoff                        555.0   125.836667
# Call to FDNY Pickup                                 201.0    40.075274
# Call_to_FDNY_Job_Creation                           201.0    99.397711
# Call to EMS Pickup                                  139.0    72.125540
# Call_to_Agency_Job_Creation                         139.0   200.765468
# Call_to_Agency_Dispatch                             555.0   164.504054
# Call_to_Agency_Arrival                              555.0   427.212378
# Call_to_First_Arrival(Multi-Agency Incidents)       555.0   391.015658
# Median Pickup                                       555.0     3.005405
# Median Calltaker Handoff                            555.0    63.039640
# ...

# %%
#NYPD
police_department.describe().T
# Out:
#                                                     count         mean  \
# of_Incidents_Calculated                             414.0  1330.579710
# Call to First Pickup                                414.0     3.588213
# Call to PD Calltaker Handoff                        414.0   132.886691
# Call to FDNY Pickup                                   0.0          NaN
# Call_to_FDNY_Job_Creation                             0.0          NaN
# Call to EMS Pickup                                    0.0          NaN
# Call_to_Agency_Job_Creation                           0.0          NaN
# Call_to_Agency_Dispatch                             414.0   292.955749
# Call_to_Agency_Arrival                              414.0   687.518575
# Call_to_First_Arrival(Multi-Agency Incidents)       414.0   671.500604
# Median Pickup                                       414.0     3.000000
# Median Calltaker Handoff                            414.0   104.753623
# ...

# %%
#EMS
emergencies.describe().T
# Out:
#                                                     count          mean  \
# of_Incidents_Calculated                             278.0  11957.276978
# Call to First Pickup                                278.0      3.635791
# Call to PD Calltaker Handoff                        278.0     72.666763
# Call to FDNY Pickup                                   0.0           NaN
# Call_to_FDNY_Job_Creation                             0.0           NaN
# Call to EMS Pickup                                  278.0     79.676835
# Call_to_Agency_Job_Creation                         278.0    117.551115
# Call_to_Agency_Dispatch                             278.0    181.372050
# Call_to_Agency_Arrival                              278.0    664.507446
# Call_to_First_Arrival(Multi-Agency Incidents)       278.0    576.839029
# Median Pickup                                       278.0      3.000000
# Median Calltaker Handoff                            278.0     77.074640
# ...
